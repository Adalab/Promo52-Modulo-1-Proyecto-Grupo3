# %%
ahorcado_pics = {
    10:"""
      
          
          
             
          
          
          
    =========""",
    9: """
          
          |
          |
          |   
          |
          |
          |
    =========""",
    8: """
      -----
          |
          |
          |   
          |
          |
          |
    =========""",
    7: """
      -----
      |   |
          |
          |   
          |
          |
          |
    =========""",
    6: """
      -----
      |   |
      O   |
          |
          |
          |
    =========""",
    5: """
      -----
      |   |
      O   |
     ( )  |
          |
          |
    =========""",
    4: """
      -----
      |   |
      O   |
    /( )  |
          |
          |
    =========""",
    3: """
      -----
      |   |
      O   |
    /( )\\ |
          |
          |
    =========""",
    2: """
      -----
      |   |
      O   |
    /( )\\ |
     /    |
          |
    =========""",
    1: """
      -----
      |   |
      O   |
    /( )\\ |
     / \\  |
          |
    =========""",
    0: """
      -----
      |   |
      X   |
    /( )\\ |
     / \\  |
          |
    ========="""
}

# %%
def obtener_dibujo_ahorcado(vidas):

    if vidas in ahorcado_pics:
        return ahorcado_pics[vidas]

# INTRODUCIR UN NUMERO DE 0 A 10:
vidas_restantes = 1
dibujo = obtener_dibujo_ahorcado(vidas_restantes)
print(f"Vidas restantes: {vidas_restantes}")
print(dibujo)
# Out:
# Vidas restantes: 1
#
#       -----
#       |   |
#       O   |
#     /( )\ |
#      / \  |
#           |
# ...
