# %% [markdown]
# ## PROYECTO1-GRUPO3- JUEGO DEL AHORCADO

# %% [markdown]
# # DEFINICION DE VARIABLES Y DICCIONARIOS

# %%
import random

# %%
# DICCIONARIO RANDOM DE PALABRAS
dic_random_words = {
    "MANZANA": "FRUTA REDONDA",
    "ELEFANTE": "GRAN TROMPA",
    "GUITARRA": "SEIS CUERDAS",
    "MONTANA": "GRAN ELEVACION",
    "ESTRELLA": "BRILLA NOCHE",
    "ORDENADOR": "PROCESA DATOS",
    "MARIPOSA": "ALAS COLORES",
    "BICICLETA": "DOS RUEDAS",
    "SOMBRERO": "CUBRE CABEZA",
    "ZANAHORIA": "RAIZ NARANJA",
    "PARAGUAS": "CONTRA LLUVIA",
    "CHOCOLATE": "DULCE CACAO",
    "AVENTURA": "EMOCIONANTE VIAJE",
    "HORIZONTE": "CIELO TIERRA",
    "SILENCIO": "SIN RUIDO",
    "PRIMAVERA": "DESPUES INVIERNO",
    "BIBLIOTECA": "GUARDA LIBROS",
    "CASTILLO": "MEDIEVAL FUERTE",
    "UNIVERSO": "TODO EXISTE",
    "MELANCOLIA": "TRISTEZA VAGA"
}
key_dic_words = list(dic_random_words.keys())
hint_dic_words = list(dic_random_words.values()) # Opcional porque no sabemos si la vamos a necesitar

# %%
# DICCIONARIO VIDAS AHORCADO (PENDIENTE DE INCLUIR DIBUJOS)

# %%
# DICCIONARIO MENSAJES DE ANIMACION
dicc_motivation = {
    10: "¡Comienzas con todas las fuerzas! ¡A por la victoria!",
    9: "¡Un pequeño tropiezo no detiene a un campeón! ¡Sigue adelante!",
    8: "¡No te rindas ahora! ¡Aún tienes mucho por jugar!",
    7: "¡Cada intento te acerca más al éxito! ¡Persiste!",
    6: "¡La mitad del camino recorrido! ¡Mantén la concentración!",
    5: "¡Ánimo, estás a punto de lograrlo! ¡No te desanimes!",
    4: "¡Casi lo tienes! ¡Un esfuerzo más!",
    3: "¡No te rindas en la recta final! ¡Puedes hacerlo!",
    2: "¡Última oportunidad! ¡Concéntrate al máximo!",
    1: "¡Todo o nada! ¡Demuestra lo que vales!"
}

# %%
# DICCIONARIO DIBUJO DEL AHORCADO
ahorcado_pics = {
    10:"""
      
          
          
             
          
          
          
    =========""",
    9: """
          
          |
          |
          |   
          |
          |
          |
    =========""",
    8: """
      -----
          |
          |
          |   
          |
          |
          |
    =========""",
    7: """
      -----
      |   |
          |
          |   
          |
          |
          |
    =========""",
    6: """
      -----
      |   |
      O   |
          |
          |
          |
    =========""",
    5: """
      -----
      |   |
      O   |
     ( )  |
          |
          |
    =========""",
    4: """
      -----
      |   |
      O   |
    /( )  |
          |
          |
    =========""",
    3: """
      -----
      |   |
      O   |
    /( )\\ |
          |
          |
    =========""",
    2: """
      -----
      |   |
      O   |
    /( )\\ |
     /    |
          |
    =========""",
    1: """
      -----
      |   |
      O   |
    /( )\\ |
     / \\  |
          |
    =========""",
    0: """
      -----
      |   |
      X   |
    /( )\\ |
     / \\  |
          |
    ========="""
}

# %%
# VARIABLES FIJAS
used_letters = {}     # Set letras usadas en partida
failed_letters = {}    # Set letras fallidas en partida
player_num = int(input("Escoge 1 o 2 jugadores"))       # Numero de jugadores de cada partida (1 o 2)
player_1 = (input("Jugador 1, por favor escribe tu nombre")).upper()   # Nombre Jugador 1
player_2 = (input("Jugador 2, por favor escribe tu nombre")).upper()  # Nombre Jugador 2
word_player = (input("Por favor, introduce una palabra a adivinar"))   # Palabra intoducida por el jugador a adivinar
word_random = random.choice(key_dic_words)         # Palabra random a adivinar
word = "" # Palabra a adivinar del jugador o random
word_hidden = len(word)*"_"  # Palabra a adivinar oculta
hint_player = (input("Por favor, introduce una pista")) # Pista de la palabra del jugador
game_continue = (input("Deseas seguir jugando? S/N"))
lives = 10            # Vidas iniciales con las que empezamos las partidas 
player_1_points = 0    # Puntos jugador1
player_2_points = 0    # Puntos jugador2
turn = 0 # Turno (par o impar)

# %%
# FUNCIONES
# 1 Dar valor a variable word:Escoger palabra a adivinar en funcion si la a metido el jugador o es random
def wordoption (player_num):
    try:
        if player_num == 1 :
            return word_random
        elif player_num == 2:
             return word_player
    except:
        print ("Has introducido un número incorrecto, por favor seleccione 1 o 2 jugadores")
# 2 Dar Pista en funcion de la cantidad de jugadores
def hintoption (player_num):
    try:
        if player_num == 1 :
            return dic_random_words.values(word_random)
        elif player_num == 2:
            return hint_player
    except:
        print ("Has introducido un número incorrecto, por favor seleccione 1 o 2 jugadores")

# 3

# %% [markdown]
# ## CODIGO DEL JUEGO DEL AHORCADO

# %%
print ("    B I E N V E N I D A S  A L  J U E G O  D E L  A R B O L  D E L  A H O R C A D O \n\n                             BY SINSAJO TECHNOLOGY")

print ("\n...................................................................................\n")

used_letters = {}     # Set letras usadas en partida
failed_letters = {}    # Set letras fallidas en partida
word_random = random.choice(key_dic_words)         # Palabra random a adivinar
word = "" # Palabra a adivinar del jugador o random
word_hidden = len(word)*"_"  # Palabra a adivinar oculta
lives = 10            # Vidas iniciales con las que empezamos las partidas 
player_1_points = 0    # Puntos jugador1
player_2_points = 0    # Puntos jugador2
turn = 0 # Turno (par o impar)

try:
    player_num = int(input("Escoge 1 o 2 jugadoras"))       # Numero de jugadores de cada partida (1 o 2)
    while player_num not in [1,2]:
         player_num = int(input("La opción introducida no es válida, escoge entre 1 o 2 jugadoras")) 
except:
     player_num = int(input("Empezamos mal... Concentración! Escoge 1 o 2 jugadoras"))  

print ("Gracias por elegir nuestro juego. Esperamos que salgais con vida y con cabeza útil que seguir exprimiendo en Adalab")

try:
    if player_num == 1:
        player_1 = (input("Jugadora 1, por favor, escribe tu nombre")).upper()   # Nombre Jugador 1
        print (f"Por lo que veo {player_1} Adalab te ha dejado sin vida social y amig@s") #Saludo al Jugador 1
    else:
        player_1 = (input("Jugadora 1, por favor, escribe tu nombre")).upper()   # Nombre Jugador 1
        player_2 = (input("Jugadora 2, por favor, escribe tu nombre")).upper()  # Nombre Jugador 2    
        print(f"Bienvenidas al juego {player_1} y {player_2}")    #Saludo al Jugador 1 y 2
except:  
    print("a")
# Out:
#     B I E N V E N I D A S  A L  J U E G O  D E L  A R B O L  D E L  A H O R C A D O
#
#                              BY SINSAJO TECHNOLOGY
#
# ...................................................................................
#
# Gracias por elegir nuestro juego. Esperamos que salgais con vida y con cabeza útil que seguir exprimiendo en Adalab
# Bienvenidas al juego L y S

# %%
player_1 = (input("Jugadora 1, por favor, escribe tu nombre")).upper()   # Nombre Jugador 1
player_2 = (input("Jugadora 2, por favor, escribe tu nombre")).upper()  # Nombre Jugador 2
word_player = (input("Por favor, introduce una palabra a adivinar"))   # Palabra intoducida por el jugador a adivinar
hint_player = (input("Por favor, introduce una pista")) # Pista de la palabra del jugador
game_continue = (input("Deseas seguir jugando? S/N"))

player_1 = (input("Jugadora, ¿Cómo quieres que me dirija a ti? '007, yo trabajo sola'")).upper()   # Nombre Jugador 1
player_1 = (input("Jugadora 1, sorprende a tu oponente con un nombre ocurrente")).upper()   # Nombre Jugador 1
player_2 = (input("Jugadora 2, dame un nombre ocurrente para dirigirme a ti, espero que sea mejor que el de tu compañera")).upper()  # Nombre Jugador 2
word_player_1 = (input(f"Por favor, dame una palabra difícil para que la intente adivinar {player_2}"))   # Palabra intoducida por el jugador a adivinar
word_player_2 = (input(f"Por favor, dame una palabra difícil para que la intente adivinar {player_1}"))   # Palabra intoducida por el jugador a adivinar
hint_player_1 = (input(f"Demasiado difícil, dale una pista a {player_2} por si no se centra")) # Pista de la palabra del jugador
hint_player_2 = (input(f"Demasiado difícil, dale una pista a {player_1} por si no se centra")) # Pista de la palabra del jugador
game_continue = (input("Poco probaste, ¿quieres volver a jugar para intentar romper mi código? S/N"))
